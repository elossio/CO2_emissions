# %% [markdown]
# # EDA and Data Processing for CO2 Emissions
#
# This notebook performs Exploratory Data Analysis (EDA) and the final processing of the database for modeling, including cleaning, feature engineering, and standardization.

# %% [markdown]
# ## 1. Imports and Configurations
#
# We configure the environment with visualization libraries and load project paths.

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from src.config import CONSOLIDATED_DATA, PROCESSED_DATA

sns.set_theme(palette="bright")

# %% [markdown]
# ## 2. Loading Consolidated Data
#
# We read the database consolidated in the previous step.

# %%
df = pd.read_parquet(CONSOLIDATED_DATA)

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4           A4         X            9.2               7.2
# 1          4           M5         X            9.1               7.3
# 2          6           A5         Z           15.9              11.1
# 3          6          AS4         Z           15.1              10.5
# 4          6           M6         Z           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ## 3. Initial Inspection and Sanity Checks
#
# We check the data structure, column types, and presence of null or duplicate values.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20521 entries, 0 to 20520
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model_year          20521 non-null  int64
#  1   make                20521 non-null  object
#  2   model               20521 non-null  object
#  3   vehicle_class       20521 non-null  object
#  4   engine_size_l       20521 non-null  float64
#  5   cylinders           20521 non-null  int64
#  6   transmission        20521 non-null  object
#  7   fuel_type           20521 non-null  object
#  8   city_l_100_km       20521 non-null  float64
#  9   highway_l_100_km    20521 non-null  float64
#  10  combined_l_100_km   20521 non-null  float64
#  11  combined_mpg        20521 non-null  int64
#  12  co2_emissions_g_km  20521 non-null  int64
#  13  co2_rating          8832 non-null   float64
#  14  smog_rating         7726 non-null   float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 2.3+ MB

# %%
with pd.option_context("display.float_format", "{:.2f}".format):
    display(df.describe())
# Out:
#        model_year  engine_size_l  cylinders  city_l_100_km  highway_l_100_km  \
# count    20521.00       20521.00   20521.00       20521.00          20521.00
# mean      2014.24           3.34       5.83          13.44              9.72
# std          5.59           1.35       1.87           3.78              2.52
# min       2005.00           0.80       2.00           4.00              3.90
# 25%       2009.00           2.20       4.00          10.80              8.00
# 50%       2014.00           3.00       6.00          13.00              9.30
# 75%       2019.00           4.00       8.00          15.50             11.00
# max       2024.00           8.40      16.00          30.70             22.10
#
#        combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# count           20521.00      20521.00            20521.00     8832.00
# mean               11.76         25.74              266.81        4.63
# std                 3.18          7.02               63.51        1.58
# min                 4.00         11.00               94.00        1.00
# 25%                 9.60         21.00              221.00        4.00
# 50%                11.30         25.00              262.00        5.00
# 75%                13.40         29.00              304.00        5.00
# max                26.10         71.00              608.00       10.00
#
#        smog_rating
# count      7726.00
# mean          4.82
# std           1.79
# min           1.00
# 25%           3.00
# 50%           5.00
# 75%           6.00
# max           8.00

# %%
df.describe(exclude="number")
# Out:
#              make    model vehicle_class transmission fuel_type
# count       20521    20521         20521        20521     20521
# unique         48     3522            17           29         5
# top     Chevrolet  Mustang      Mid-size          AS6         X
# freq         1884       96          2736         2876     10179

# %% [markdown]
# ## 4. Processing the Transmission Variable
#
# We extract the number of gears and simplify transmission categories.

# %%
# Gear extraction and category simplification
df["gears"] = df["transmission"].str.extract(r"(\d+)").astype("float")

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4           A4         X            9.2               7.2
# 1          4           M5         X            9.1               7.3
# 2          6           A5         Z           15.9              11.1
# 3          6          AS4         Z           15.1              10.5
# 4          6           M6         Z           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating  gears
# 0          NaN    4.0
# 1          NaN    5.0
# 2          NaN    5.0
# 3          NaN    4.0
# 4          NaN    6.0

# %%
df["transmission"] = df["transmission"].str.replace(r"(\d+)", "", regex=True)

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4            A         X            9.2               7.2
# 1          4            M         X            9.1               7.3
# 2          6            A         Z           15.9              11.1
# 3          6           AS         Z           15.1              10.5
# 4          6            M         Z           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating  gears
# 0          NaN    4.0
# 1          NaN    5.0
# 2          NaN    5.0
# 3          NaN    4.0
# 4          NaN    6.0

# %%
df.describe(exclude="number")
# Out:
#              make    model vehicle_class transmission fuel_type
# count       20521    20521         20521        20521     20521
# unique         48     3522            17            5         5
# top     Chevrolet  Mustang      Mid-size           AS         X
# freq         1884       96          2736         7189     10179

# %% [markdown]
# ## 5. Fuel Variable Treatment
#
# We mapped the fuel codes to readable and standardized names.

# %%
fuel = {
    "X": "reg_gasoline",
    "Z": "premium_gasoline",
    "D": "diesel",
    "E": "ethanol",
    "N": "natural_gas",
}

df["fuel_type"] = df["fuel_type"].map(fuel)

df.head()
# Out:
#    model_year   make    model          vehicle_class  engine_size_l  \
# 0        2005  Acura    1.7EL                Compact            1.7
# 1        2005  Acura    1.7EL                Compact            1.7
# 2        2005  Acura  MDX AWD  Sport utility vehicle            3.5
# 3        2005  Acura      NSX             Two-seater            3.0
# 4        2005  Acura      NSX             Two-seater            3.2
#
#    cylinders transmission         fuel_type  city_l_100_km  highway_l_100_km  \
# 0          4            A      reg_gasoline            9.2               7.2
# 1          4            M      reg_gasoline            9.1               7.3
# 2          6            A  premium_gasoline           15.9              11.1
# 3          6           AS  premium_gasoline           15.1              10.5
# 4          6            M  premium_gasoline           15.1              10.5
#
#    combined_l_100_km  combined_mpg  co2_emissions_g_km  co2_rating  \
# 0                8.3            34                 191         NaN
# 1                8.3            34                 191         NaN
# 2               13.7            21                 315         NaN
# 3               13.0            22                 299         NaN
# 4               13.0            22                 299         NaN
#
#    smog_rating  gears
# 0          NaN    4.0
# 1          NaN    5.0
# 2          NaN    5.0
# 3          NaN    4.0
# 4          NaN    6.0

# %%
df[df == 0].count()
# Out:
# model_year            0
# make                  0
# model                 0
# vehicle_class         0
# engine_size_l         0
# cylinders             0
# transmission          0
# fuel_type             0
# city_l_100_km         0
# highway_l_100_km      0
# combined_l_100_km     0
# combined_mpg          0
# co2_emissions_g_km    0
# co2_rating            0
# smog_rating           0
# gears                 0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# model_year                0
# make                      0
# model                     0
# vehicle_class             0
# engine_size_l             0
# cylinders                 0
# transmission              0
# fuel_type                 0
# city_l_100_km             0
# highway_l_100_km          0
# combined_l_100_km         0
# combined_mpg              0
# co2_emissions_g_km        0
# co2_rating            11689
# smog_rating           12795
# gears                   864
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 6. Cleaning and Selection of Columns
#
# We remove redundant columns or those that do not contribute to modeling.

# %%
df = df.drop(columns=["combined_mpg", "model"])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20521 entries, 0 to 20520
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model_year          20521 non-null  int64
#  1   make                20521 non-null  object
#  2   vehicle_class       20521 non-null  object
#  3   engine_size_l       20521 non-null  float64
#  4   cylinders           20521 non-null  int64
#  5   transmission        20521 non-null  object
#  6   fuel_type           20521 non-null  str
#  7   city_l_100_km       20521 non-null  float64
#  8   highway_l_100_km    20521 non-null  float64
#  9   combined_l_100_km   20521 non-null  float64
#  10  co2_emissions_g_km  20521 non-null  int64
#  11  co2_rating          8832 non-null   float64
#  12  smog_rating         7726 non-null   float64
#  13  gears               19657 non-null  float64
# dtypes: float64(7), int64(3), object(3), str(1)
# memory usage: 2.2+ MB

# %%
df.nunique()
# Out:
# model_year             20
# make                   48
# vehicle_class          17
# engine_size_l          61
# cylinders               9
# transmission            5
# fuel_type               5
# city_l_100_km         237
# highway_l_100_km      168
# combined_l_100_km     207
# co2_emissions_g_km    374
# co2_rating             10
# smog_rating             7
# gears                   8
# dtype: int64

# %% [markdown]
# ## 7. Initial Exploratory Analysis
#
# We explored the distributions of the remaining categorical variables.

# %%
df["make"].value_counts()
# Out:
# make
# Chevrolet        1884
# Ford             1538
# BMW              1364
# Mercedes-Benz    1202
# GMC              1179
# Porsche          1008
# Toyota            907
# Audi              778
# Dodge             744
# Nissan            681
# Volkswagen        585
# Jeep              549
# Hyundai           540
# Kia               531
# Mazda             524
# Honda             520
# Lexus             463
# Subaru            456
# Cadillac          453
# MINI              443
# Volvo             419
# Jaguar            339
# Chrysler          324
# Mitsubishi        292
# Infiniti          258
# Buick             243
# Land Rover        235
# Acura             211
# Lincoln           205
# Ram               165
# Pontiac           158
# Maserati          153
# Bentley           127
# Suzuki            127
# Lamborghini       123
# Aston Martin      118
# Rolls-Royce       116
# Saab              115
# FIAT               86
# Saturn             83
# Genesis            60
# Alfa Romeo         56
# Ferrari            52
# Scion              44
# smart              22
# Hummer             21
# Bugatti            16
# SRT                 4
# Name: count, dtype: int64

# %%
categoricas = df.select_dtypes(include="object").columns

categoricas = categoricas.to_list()

categoricas
# Out:
# /tmp/ipykernel_3781/745893037.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categoricas = df.select_dtypes(include="object").columns
# ['make', 'vehicle_class', 'transmission', 'fuel_type']

# %%
categoricas.extend(["model_year", "cylinders", "gears"])

categoricas
# Out:
# ['make',
#  'vehicle_class',
#  'transmission',
#  'fuel_type',
#  'model_year',
#  'cylinders',
#  'gears']

# %%
fig, axs = plt.subplots(7, 1, figsize=(10, 40))

for ax, coluna in zip(axs.flatten(), categoricas):
    sns.countplot(
        data=df,
        x=coluna,
        ax=ax,
        order=df[coluna].value_counts().index[:20]
    )
    ax.bar_label(ax.containers[0])
    ax.tick_params(axis="x", rotation=90)

plt.tight_layout()
plt.show()

# %%
df[df["gears"] == 1]
# Out:
#        model_year     make                 vehicle_class  engine_size_l  \
# 17419        2021  Hyundai                      Mid-size            2.0
# 17420        2021  Hyundai                      Mid-size            2.0
# 17443        2021  Hyundai                      Mid-size            1.6
# 17512        2021      Kia                       Compact            1.6
# 18394        2022  Hyundai                      Mid-size            2.0
# 18395        2022  Hyundai                      Mid-size            2.0
# 18421        2022  Hyundai                      Mid-size            1.6
# 18490        2022      Kia                       Compact            1.6
# 19326        2023  Hyundai                      Mid-size            2.0
# 19327        2023  Hyundai                      Mid-size            2.0
# 19347        2023  Hyundai                      Mid-size            1.6
# 19405        2023      Kia                       Compact            1.6
# 20093        2024  Hyundai                      Mid-size            2.0
# 20094        2024  Hyundai                      Mid-size            2.0
# 20098        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20099        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20101        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20102        2024  Hyundai  Sport utility vehicle: Small            2.0
# 20114        2024  Hyundai  Sport utility vehicle: Small            1.6
#
#        cylinders transmission     fuel_type  city_l_100_km  highway_l_100_km  \
# 17419          4           AV  reg_gasoline            7.5               5.7
# 17420          4           AV  reg_gasoline            7.1               5.5
# 17443          4           AV  reg_gasoline            7.9               7.0
# 17512          4           AV  reg_gasoline            7.2               6.0
# 18394          4           AV  reg_gasoline            7.6               5.7
# 18395          4           AV  reg_gasoline            7.1               5.5
# 18421          4           AV  reg_gasoline            7.9               6.9
# 18490          4           AV  reg_gasoline            7.2               6.0
# 19326          4           AV  reg_gasoline            7.6               5.7
# 19327          4           AV  reg_gasoline            7.1               5.5
# 19347          4           AV  reg_gasoline            7.9               6.9
# 19405          4           AV  reg_gasoline            7.2               6.1
# 20093          4           AV  reg_gasoline            7.6               5.9
# 20094          4           AV  reg_gasoline            7.3               5.7
# 20098          4           AV  reg_gasoline            8.4               6.7
# 20099          4           AV  reg_gasoline            8.1               6.8
# 20101          4           AV  reg_gasoline            9.0               8.1
# 20102          4           AV  reg_gasoline            8.8               8.1
# 20114          4           AV  reg_gasoline            7.9               6.9
#
#        combined_l_100_km  co2_emissions_g_km  co2_rating  smog_rating  gears
# 17419                6.7                 157         7.0          5.0    1.0
# 17420                6.4                 152         8.0          5.0    1.0
# 17443                7.5                 178         7.0          5.0    1.0
# 17512                6.7                 159         7.0          3.0    1.0
# 18394                6.7                 158         7.0          5.0    1.0
# 18395                6.4                 151         7.0          5.0    1.0
# 18421                7.5                 176         7.0          5.0    1.0
# 18490                6.7                 159         7.0          3.0    1.0
# 19326                6.7                 158         7.0          5.0    1.0
# 19327                6.4                 151         7.0          5.0    1.0
# 19347                7.5                 177         6.0          5.0    1.0
# 19405                6.7                 160         7.0          3.0    1.0
# 20093                6.8                 160         7.0          7.0    1.0
# 20094                6.5                 153         7.0          7.0    1.0
# 20098                7.6                 179         6.0          7.0    1.0
# 20099                7.5                 177         6.0          7.0    1.0
# 20101                8.6                 201         6.0          7.0    1.0
# 20102                8.5                 198         6.0          7.0    1.0
# 20114                7.5                 177         6.0          5.0    1.0

# %%
pd.crosstab(df["gears"], df["transmission"], dropna=False)
# Out:
# transmission     A   AM    AS   AV     M
# gears
# 1.0              0    0     0   19     0
# 4.0           1850    0   162    0     1
# 5.0            889    6   673    0  1164
# 6.0           1944  215  2876  159  2524
# 7.0            276  794   621  157   151
# 8.0            989  232  2193  124     0
# 9.0            650    6   158    0     0
# 10.0           279    0   506   39     0
# NaN              0    0     0  864     0

# %%
fig, axs = plt.subplots(2, 5, figsize=(20, 10))

for ax, coluna in zip(axs.flatten(), df.select_dtypes("number").columns):
    sns.histplot(data=df, x=coluna, ax=ax, kde=True)

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 5, figsize=(20, 10))

for ax, coluna in zip(axs.flatten(), df.select_dtypes("number").columns):
    sns.boxplot(data=df, x=coluna, ax=ax, showmeans=True)

plt.tight_layout()
plt.show()

# %%
corr = df.select_dtypes("number").corr()

matriz = np.triu(corr)

fig, ax = plt.subplots(figsize=(8, 8))

sns.heatmap(
    corr,
    mask=matriz,
    annot=True,
    fmt=".2f",
    ax=ax,
    annot_kws={"fontsize": 8}
)

plt.show()

# %%
co2_latex = r"CO$_2$"

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=df,
    x="make",
    y="co2_emissions_g_km",
    ax=ax,
    order=df.groupby("make")["co2_emissions_g_km"].mean().sort_values(ascending=False).index,
    capsize=0.2
)

ax.bar_label(
    ax.containers[0],
    fmt="%.1f",
    rotation=90,
    padding=12,
    size=10,
    weight="bold"
)

ax.set_ylim(0, 630)
ax.set_ylabel("")
ax.set_xlabel("")
ax.set_yticks([])
ax.set_title(f"Média de emissão de {co2_latex} por fabricante (g/km)")
plt.xticks(rotation=90)

norm = mcolors.Normalize(
    vmin=df["co2_emissions_g_km"].min(),
    vmax=df["co2_emissions_g_km"].max(),
)
cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=df,
    x="vehicle_class",
    y="co2_emissions_g_km",
    ax=ax,
    order=df.groupby("vehicle_class")["co2_emissions_g_km"].mean().sort_values(ascending=False).index,
    capsize=0.2
)

ax.bar_label(
    ax.containers[0],
    fmt="%.1f",
    rotation=90,
    padding=12,
    size=10,
    weight="bold"
)

ax.set_ylim(0, 440)
ax.set_ylabel("")
ax.set_xlabel("")
ax.set_yticks([])
ax.set_title(f"Média de emissão de {co2_latex} por classe de veículo (g/km)")
plt.xticks(rotation=90)

norm = mcolors.Normalize(
    vmin=df["co2_emissions_g_km"].min(),
    vmax=df["co2_emissions_g_km"].max(),
)
cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=df,
    x="fuel_type",
    y="co2_emissions_g_km",
    ax=ax,
    order=df.groupby("fuel_type")["co2_emissions_g_km"].mean().sort_values(ascending=False).index,
    capsize=0.2
)

ax.bar_label(
    ax.containers[0],
    fmt="%.1f",
    rotation=90,
    padding=12,
    size=10,
    weight="bold"
)

# retirando labels e colocando título
ax.set_ylim(0, 330)
ax.set_ylabel("")
ax.set_xlabel("")
ax.set_yticks([])
ax.set_title(f"Média de emissão de {co2_latex} por tipo de combustível (g/km)")
plt.xticks(rotation=90)

# escala de cores
norm = mcolors.Normalize(
    vmin=df["co2_emissions_g_km"].min(),
    vmax=df["co2_emissions_g_km"].max(),
)
cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=df,
    x="model_year",
    y="co2_emissions_g_km",
    ax=ax,
    capsize=0.2
)

ax.bar_label(
    ax.containers[0],
    fmt="%.1f",
    rotation=90,
    padding=12,
    size=10,
    weight="bold"
)

ax.set_ylim(0, 330)
ax.set_ylabel("")
ax.set_xlabel("")
ax.set_yticks([])
ax.set_title(f"Média de emissão de {co2_latex} por tipo de combustível (g/km)")
plt.xticks(rotation=90)

norm = mcolors.Normalize(
    vmin=df["co2_emissions_g_km"].min(),
    vmax=df["co2_emissions_g_km"].max(),
)
cmap = cm.RdYlGn_r

for barra in ax.patches:
    barra.set_color(cmap(norm(barra.get_height())))

plt.show()

# %%
pd.crosstab(df["model_year"], df["vehicle_class"])
# Out:
# vehicle_class  Compact  Full-size  Mid-size  Minicompact  Minivan  \
# model_year
# 2005               146         45       114           74       33
# 2006               137         56       111           37       35
# 2007               116         54       139           47       34
# 2008               148         63       134           49       22
# 2009               152         68       125           43       16
# 2010               144         77       120           41       14
# 2011               128         71       132           53       14
# 2012               137         81       132           76       16
# 2013               175         77       157           53       15
# 2014               172         86       179           47       14
# 2015               186         93       180           59       15
# 2016               181         90       188           52       12
# 2017               159         82       162           44       12
# 2018               122        109       158           53       11
# 2019               106        101       145           56        9
# 2020               109         78       128           23        8
# 2021                85         65       116           30        7
# 2022                70         65       118           45        7
# 2023                63         48       114           22        7
# 2024                50         36        84           49        7
#
# vehicle_class  Pickup truck: Small  Pickup truck: Standard  \
# model_year
# 2005                             0                     127
# 2006                             0                     141
# 2007                             0                     154
# 2008                            52                      72
# 2009                            59                      95
# 2010                            54                      73
# 2011                            51                      85
# 2012                            43                      79
# 2013                            12                      84
# 2014                            12                      60
# 2015                            22                      49
# 2016                            26                      59
# 2017                            28                      75
# 2018                            27                      97
# 2019                            25                      99
# 2020                            19                      91
# 2021                            17                     115
# 2022                            20                     113
# 2023                            17                      97
# 2024                            19                      79
#
# vehicle_class  Special purpose vehicle  Sport utility vehicle  \
# model_year
# 2005                                 0                    224
# 2006                                 0                    221
# 2007                                 0                    240
# 2008                                 0                    267
# 2009                                 0                    268
# 2010                                 1                    251
# 2011                                 1                    270
# 2012                                 2                    239
# 2013                                 5                      0
# 2014                                 7                      0
# 2015                                 9                      0
# 2016                                17                      0
# 2017                                10                      0
# 2018                                10                      0
# 2019                                14                      0
# 2020                                13                      0
# 2021                                13                      0
# 2022                                12                      0
# 2023                                 5                      0
# 2024                                 0                      0
#
# vehicle_class  Sport utility vehicle: Small  Sport utility vehicle: Standard  \
# model_year
# 2005                                      0                                0
# 2006                                      0                                0
# 2007                                      0                                0
# 2008                                      0                                0
# 2009                                      0                                0
# 2010                                      0                                0
# 2011                                      0                                0
# 2012                                      0                                0
# 2013                                    139                              109
# 2014                                    156                              110
# 2015                                    179                               98
# 2016                                    180                              106
# 2017                                    174                              102
# 2018                                    177                              103
# 2019                                    174                              111
# 2020                                    188                              122
# 2021                                    204                              143
# 2022                                    208                              156
# 2023                                    195                              139
# 2024                                    184                              131
#
# vehicle_class  Station wagon: Mid-size  Station wagon: Small  Subcompact  \
# model_year
# 2005                                38                    54          87
# 2006                                28                    53          78
# 2007                                32                    44          83
# 2008                                18                    43         100
# 2009                                13                    56          99
# 2010                                 9                    63          98
# 2011                                 4                    59         104
# 2012                                 5                    50         102
# 2013                                 3                    47          96
# 2014                                 6                    36          64
# 2015                                 8                    35          92
# 2016                                 7                    37          76
# 2017                                 8                    45          93
# 2018                                10                    39          96
# 2019                                 9                    37          98
# 2020                                 8                    25          95
# 2021                                 9                    20          83
# 2022                                 8                    19          79
# 2023                                 9                    14          75
# 2024                                 6                    11          63
#
# vehicle_class  Two-seater  Van: Cargo  Van: Passenger
# model_year
# 2005                   52          13              12
# 2006                   49          14               8
# 2007                   61          27              12
# 2008                   73          26              12
# 2009                   64          26              12
# 2010                   59          18               8
# 2011                   64          22              27
# 2012                   76          22              31
# 2013                   58          22              30
# 2014                   72          22              25
# 2015                   84           0              19
# 2016                   68           0               7
# 2017                   57           0               7
# 2018                   69           0               2
# 2019                   70           0               2
# 2020                   64           0               4
# 2021                   59           0               4
# 2022                   56           0               0
# 2023                   35           0               0
# 2024                   49           0               0

# %%
pd.crosstab(df["model_year"], df["fuel_type"])
# Out:
# fuel_type   diesel  ethanol  natural_gas  premium_gasoline  reg_gasoline
# model_year
# 2005            14       30            0               432           543
# 2006            12       23            0               389           544
# 2007             5       53            0               429           556
# 2008             5       48            0               480           546
# 2009            10       71            0               439           576
# 2010            14       71            0               408           537
# 2011            15      104            0               421           545
# 2012            16      104            0               432           539
# 2013            19      110            0               429           524
# 2014            23       92            0               435           518
# 2015            30       64            0               501           533
# 2016            21       57            1               461           566
# 2017            15       49            0               439           555
# 2018            28       47            0               484           524
# 2019            27       38            0               491           500
# 2020            20       23            0               489           443
# 2021            29       14            0               470           457
# 2022            28       14            0               486           448
# 2023            20       16            0               414           390
# 2024            18        6            0               409           335

# %%
df[df["fuel_type"] == "natural_gas"]
# Out:
#        model_year       make vehicle_class  engine_size_l  cylinders  \
# 11925        2016  Chevrolet      Mid-size            3.6          6
#
#       transmission    fuel_type  city_l_100_km  highway_l_100_km  \
# 11925           AS  natural_gas           15.2               9.5
#
#        combined_l_100_km  co2_emissions_g_km  co2_rating  smog_rating  gears
# 11925               12.7                 213         6.0          NaN    6.0

# %%
df = df.drop(df[df["fuel_type"] == "natural_gas"].index)

df["fuel_type"].value_counts()
# Out:
# fuel_type
# reg_gasoline        10179
# premium_gasoline     8938
# ethanol              1034
# diesel                369
# Name: count, dtype: int64

# %%
pd.crosstab(df["model_year"], df["fuel_type"]).style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_171e0_row0_col0, #T_171e0_row5_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_171e0_row0_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_171e0_row0_col2, #T_171e0_row7_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_171e0_row0_col3 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_171e0_row1_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_171e0_row1_col1, #T_171e0_row15_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_171e0_row1_col2, #T_171e0_row2_col0, #T_171e0_row3_col0, #T_171e0_row19_col1, #T_171e0_row19_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_171e0_row1_col3 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_171e0_row2_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_171e0_row2_col2, #T_171e0_row8_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_171e0_row2_col3 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_171e0_row3_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_171e0_row3_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_171e0_row3_col3 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_171e0_row4_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_171e0_row4_col1, #T_171e0_row5_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_171e0_row4_col2, #T_171e0_row12_col2, #T_171e0_row15_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_171e0_row4_col3, #T_171e0_row8_col1, #T_171e0_row10_col0, #T_171e0_row10_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_171e0_row5_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_171e0_row5_col3 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_171e0_row6_col0, #T_171e0_row12_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_171e0_row6_col1, #T_171e0_row7_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_171e0_row6_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_171e0_row6_col3 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_171e0_row7_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_171e0_row7_col3 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_171e0_row8_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_171e0_row8_col3, #T_171e0_row13_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_171e0_row9_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_171e0_row9_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_171e0_row9_col2, #T_171e0_row12_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_171e0_row9_col3 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_171e0_row10_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_171e0_row10_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_171e0_row11_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_171e0_row11_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_171e0_row11_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_171e0_row11_col3, #T_171e0_row16_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_171e0_row12_col3, #T_171e0_row14_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_171e0_row13_col0, #T_171e0_row17_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_171e0_row13_col1 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_171e0_row13_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_171e0_row14_col0 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_171e0_row14_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_171e0_row14_col3 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_171e0_row15_col0, #T_171e0_row18_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_171e0_row15_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_171e0_row16_col1, #T_171e0_row17_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_171e0_row16_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_171e0_row16_col3 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_171e0_row17_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_171e0_row17_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_171e0_row18_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_171e0_row18_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_171e0_row18_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_171e0_row19_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_171e0_row19_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_171e0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >fuel_type</th>
#       <th id="T_171e0_level0_col0" class="col_heading level0 col0" >diesel</th>
#       <th id="T_171e0_level0_col1" class="col_heading level0 col1" >ethanol</th>
#       <th id="T_171e0_level0_col2" class="col_heading level0 col2" >premium_gasoline</th>
#       <th id="T_171e0_level0_col3" class="col_heading level0 col3" >reg_gasoline</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_171e0_level0_row0" class="row_heading level0 row0" >2005</th>
#       <td id="T_171e0_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_171e0_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_171e0_row0_col2" class="data row0 col2" >432</td>
#       <td id="T_171e0_row0_col3" class="data row0 col3" >543</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row1" class="row_heading level0 row1" >2006</th>
#       <td id="T_171e0_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_171e0_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_171e0_row1_col2" class="data row1 col2" >389</td>
#       <td id="T_171e0_row1_col3" class="data row1 col3" >544</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row2" class="row_heading level0 row2" >2007</th>
#       <td id="T_171e0_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_171e0_row2_col1" class="data row2 col1" >53</td>
#       <td id="T_171e0_row2_col2" class="data row2 col2" >429</td>
#       <td id="T_171e0_row2_col3" class="data row2 col3" >556</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row3" class="row_heading level0 row3" >2008</th>
#       <td id="T_171e0_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_171e0_row3_col1" class="data row3 col1" >48</td>
#       <td id="T_171e0_row3_col2" class="data row3 col2" >480</td>
#       <td id="T_171e0_row3_col3" class="data row3 col3" >546</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row4" class="row_heading level0 row4" >2009</th>
#       <td id="T_171e0_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_171e0_row4_col1" class="data row4 col1" >71</td>
#       <td id="T_171e0_row4_col2" class="data row4 col2" >439</td>
#       <td id="T_171e0_row4_col3" class="data row4 col3" >576</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row5" class="row_heading level0 row5" >2010</th>
#       <td id="T_171e0_row5_col0" class="data row5 col0" >14</td>
#       <td id="T_171e0_row5_col1" class="data row5 col1" >71</td>
#       <td id="T_171e0_row5_col2" class="data row5 col2" >408</td>
#       <td id="T_171e0_row5_col3" class="data row5 col3" >537</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row6" class="row_heading level0 row6" >2011</th>
#       <td id="T_171e0_row6_col0" class="data row6 col0" >15</td>
#       <td id="T_171e0_row6_col1" class="data row6 col1" >104</td>
#       <td id="T_171e0_row6_col2" class="data row6 col2" >421</td>
#       <td id="T_171e0_row6_col3" class="data row6 col3" >545</td>
#     </tr>
#     <tr>
#       <th id="T_171e0_level0_row7" class="row_heading level0 row7" >2012</th>
#       <td id="T_171e0_row7_col0" class="data row7 col0" >16</td>
#       <td id="T_171e0_row7_col1" class="data row7 col1" >104</td>
#       <td id="T_171e0_row7_col2" class="data ro

# %%
pd.crosstab(
    df["model_year"], df["fuel_type"], values=df["co2_emissions_g_km"], aggfunc="mean"
).style.background_gradient(cmap="RdYlGn_r", axis=None)
# Out:
# <style type="text/css">
# #T_a7fb9_row0_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_a7fb9_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a7fb9_row0_col2 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_a7fb9_row0_col3 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_a7fb9_row1_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a7fb9_row1_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_a7fb9_row1_col2, #T_a7fb9_row2_col0, #T_a7fb9_row3_col2, #T_a7fb9_row5_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_a7fb9_row1_col3, #T_a7fb9_row9_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_a7fb9_row2_col1 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_a7fb9_row2_col2, #T_a7fb9_row4_col1 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_a7fb9_row2_col3, #T_a7fb9_row16_col1 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_a7fb9_row3_col0, #T_a7fb9_row6_col1 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_a7fb9_row3_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_a7fb9_row3_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_a7fb9_row4_col0 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_a7fb9_row4_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_a7fb9_row4_col3 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_a7fb9_row5_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_a7fb9_row5_col2 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_a7fb9_row5_col3 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_a7fb9_row6_col0 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_a7fb9_row6_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_a7fb9_row6_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a7fb9_row7_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_a7fb9_row7_col1 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_a7fb9_row7_col2 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_a7fb9_row7_col3 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_a7fb9_row8_col0 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_a7fb9_row8_col1 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_a7fb9_row8_col2, #T_a7fb9_row18_col0 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_a7fb9_row8_col3 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_a7fb9_row9_col0 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_a7fb9_row9_col2 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_a7fb9_row9_col3 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_a7fb9_row10_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_a7fb9_row10_col1, #T_a7fb9_row12_col2, #T_a7fb9_row15_col0 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_a7fb9_row10_col2 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_a7fb9_row10_col3, #T_a7fb9_row11_col3, #T_a7fb9_row13_col0, #T_a7fb9_row15_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_a7fb9_row11_col0 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_a7fb9_row11_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_a7fb9_row11_col2 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_a7fb9_row12_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_a7fb9_row12_col1, #T_a7fb9_row13_col2, #T_a7fb9_row14_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_a7fb9_row12_col3, #T_a7fb9_row19_col3 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_a7fb9_row13_col1, #T_a7fb9_row15_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_a7fb9_row13_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_a7fb9_row14_col0 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_a7fb9_row14_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_a7fb9_row14_col3 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_a7fb9_row15_col1 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_a7fb9_row16_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_a7fb9_row16_col2, #T_a7fb9_row17_col2 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_a7fb9_row16_col3, #T_a7fb9_row18_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_a7fb9_row17_col0 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_a7fb9_row17_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_a7fb9_row17_col3 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_a7fb9_row18_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_a7fb9_row18_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_a7fb9_row19_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_a7fb9_row19_col1 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_a7fb9_row19_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# </style>
# <table id="T_a7fb9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >fuel_type</th>
#       <th id="T_a7fb9_level0_col0" class="col_heading level0 col0" >diesel</th>
#       <th id="T_a7fb9_level0_col1" class="col_heading level0 col1" >ethanol</th>
#       <th id="T_a7fb9_level0_col2" class="col_heading level0 col2" >premium_gasoline</th>
#       <th id="T_a7fb9_level0_col3" class="col_heading level0 col3" >reg_gasoline</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model_year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7fb9_level0_row0" class="row_heading level0 row0" >2005</th>
#       <td id="T_a7fb9_row0_col0" class="data row0 col0" >215.000000</td>
#       <td id="T_a7fb9_row0_col1" class="data row0 col1" >338.666667</td>
#       <td id="T_a7fb9_row0_col2" class="data row0 col2" >299.574074</td>
#       <td id="T_a7fb9_row0_col3" class="data row0 col3" >292.445672</td>
#     </tr>
#     <tr>
#       <th id="T_a7fb9_level0_row1" class="row_heading level0 row1" >2006</th>
#       <td id="T_a7fb9_row1_col0" class="data row1 col0" >196.750000</td>
#       <td id="T_a7fb9_row1_col1" class="data row1 col1" >330.826087</td>
#       <td id="T_a7fb9_row1_col2" class="data row1 col2" >297.133676</td>
#       <td id="T_a7fb9_row1_col3" class="data row1 col3" >291.117647</td>
#     </tr>
#     <tr>
#       <th id="T_a7fb9_level0_row2" class="row_heading level0 row2" >2007</th>
#       <td id="T_a7fb9_row2_col0" class="data row2 col0" >297.400000</td>
#       <td id="T_a7fb9_row2_col1" class="data row2 col1" >318.113208</td>
#       <td id="T_a7fb9_row2_col2" class="data row2 col2" >296.916084</td>
#       <td id="T_a7fb9_row2_col3" class="data row2 col3" >287.377698</td>
#     </tr>
#     <tr>
#       <th id="T_a7fb9_level0_row3" class="row_heading level0 row3" >2008</th>
#       <td id="T_a7fb9_row3_col0" class="data row3 col0" >300.200000</td>
#       <td id="T_a7fb9_row3_col1" class="data row3 col1" >310.083333</td>
#       <td id="T_a7fb9_row3_col2" class="data row3 col2" >297.243750</td>
#       <td id="T_a7fb9_row3_col3" class="data row3 col3" >281.556777</td>
#     </tr>
#     <tr>
#       <th id="T_a7fb9_level0_row4" class="row_heading level0 row4" >2009</th>
#       <td id="T_a7fb9_row4_col0" class="data row4 col0" >251.300000</td>
#       <td id="T_a7fb9_row4_col1" class="data row4 col1" >297.070423</td>
#       <td id="T_a7fb9_row4_col2" class="data row4 col2" >301.733485</td>
#       <td id="T_a7fb9_row4_col3" class="data row4 col3" >274.781250</td>
#     </tr>
#     <tr>
#       <th id="T_a7fb9_level0_row5" class="row_heading level0 row5" >2010</th>
#       <td id="T_a7fb9_row5_col0" class="data row5 col0" >248.214286</td>
#       <td id="T_a7fb9_row5_col1" class="data row5 col1" >297.507042</td>
#       <td id="T_a7fb9_row5_col2" class="data row5 col2" >298.546569</td>
#       <td id="T_a7fb9_row5_col3" class="data row5 col3" >260.620112</td>
#     </tr>
#     <tr>
#       <th id="T_a7fb9_level0_row6" class="row_heading level0 row6" >2011</th>
#       <td id="T_a7fb9_row6_col0" class="data row6 col0" >247.266667</td>
#       <td id="T_a7fb9_row6_col1" class="data row6 col1" >300.288462</td>
#       <td

# %%
fig, ax = plt.subplots(figsize=(6, 6))

sns.histplot(data=df, x="city_l_100_km", kde=True, ax=ax, label="city")
sns.histplot(data=df, x="highway_l_100_km", kde=True, ax=ax, label="highway")

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x="combined_l_100_km",
    y="co2_emissions_g_km",
    ax=ax,
    hue="fuel_type",
    alpha=0.5
)

plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x="combined_l_100_km",
    y="co2_emissions_g_km",
    ax=ax,
    hue="transmission",
    alpha=0.5
)

plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x="engine_size_l",
    y="co2_emissions_g_km",
    ax=ax,
    hue="fuel_type",
    alpha=0.5
)

plt.show()

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x="combined_l_100_km",
    y="co2_emissions_g_km",
    ax=ax,
    hue="vehicle_class",
    alpha=0.5
)

ax.legend(loc="upper left", bbox_to_anchor=(0, 1.2), ncol=4, bbox_transform=fig.transFigure)

plt.show()

# %%
class_map = {
    "Two-seater": "car",
    "Minicompact": "car",
    "Subcompact": "car",
    "Compact": "car",
    "Mid-size": "car",
    "Full-size": "car",
    "Station wagon: Small": "station_wagon",
    "Station wagon: Mid-size": "station_wagon",
    "Pickup truck: Small": "pickup_truck",
    "Pickup truck: Standard": "pickup_truck",
    "Sport utility vehicle": "suv",
    "Sport utility vehicle: Small": "suv",
    "Sport utility vehicle: Standard": "suv",
    "Minivan": "van",
    "Van: Cargo": "van",
    "Van: Passenger": "van",
    "Special purpose vehicle": "special_purpose",
}

df["vehicle_class_grouped"] = df["vehicle_class"].map(class_map)

df["vehicle_class_grouped"].value_counts(dropna=False)
# Out:
# vehicle_class_grouped
# car                10719
# suv                 5568
# pickup_truck        2347
# station_wagon       1025
# van                  742
# special_purpose      119
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()

sns.scatterplot(
    data=df,
    x="combined_l_100_km",
    y="co2_emissions_g_km",
    ax=ax,
    hue="vehicle_class_grouped",
    alpha=0.5
)

ax.legend(loc="upper left", bbox_to_anchor=(0, 1.1), ncol=3, bbox_transform=fig.transFigure)

plt.show()

# %%
pd.crosstab(df["vehicle_class_grouped"], df["fuel_type"])
# Out:
# fuel_type              diesel  ethanol  premium_gasoline  reg_gasoline
# vehicle_class_grouped
# car                       104      197              6669          3749
# pickup_truck              102      330               117          1798
# special_purpose             0       15                21            83
# station_wagon              28        1               446           550
# suv                       135      294              1682          3457
# van                         0      197                 3           542

# %%
df = df.drop(
    columns=[
        "make",
        "co2_rating",
        "smog_rating",
        "gears",
        "vehicle_class",
    ]
)

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20520 entries, 0 to 20520
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_year             20520 non-null  int64
#  1   engine_size_l          20520 non-null  float64
#  2   cylinders              20520 non-null  int64
#  3   transmission           20520 non-null  object
#  4   fuel_type              20520 non-null  str
#  5   city_l_100_km          20520 non-null  float64
#  6   highway_l_100_km       20520 non-null  float64
#  7   combined_l_100_km      20520 non-null  float64
#  8   co2_emissions_g_km     20520 non-null  int64
#  9   vehicle_class_grouped  20520 non-null  str
# dtypes: float64(4), int64(3), object(1), str(2)
# memory usage: 1.7+ MB

# %%
sns.pairplot(
    df,
    kind="reg",
    diag_kind="kde",
    plot_kws={"line_kws": {"color": "red"}, "scatter_kws": {"alpha": 0.25}}
)

# %%
df.nunique()
# Out:
# model_year                20
# engine_size_l             61
# cylinders                  9
# transmission               5
# fuel_type                  4
# city_l_100_km            237
# highway_l_100_km         168
# combined_l_100_km        207
# co2_emissions_g_km       374
# vehicle_class_grouped      6
# dtype: int64

# %%
df["engine_size_l"].value_counts()
# Out:
# engine_size_l
# 2.0    3142
# 3.0    2062
# 3.5    1420
# 2.5    1407
# 3.6    1194
#        ...
# 2.1       5
# 2.6       4
# 0.8       3
# 0.9       3
# 5.8       2
# Name: count, Length: 61, dtype: int64

# %%
df["engine_size_l"].value_counts(bins=4).sort_index()
# Out:
# (0.791, 2.7]    8365
# (2.7, 4.6]      8042
# (4.6, 6.5]      3920
# (6.5, 8.4]       193
# Name: count, dtype: int64

# %%
df["engine_size_l_class"] = pd.cut(
    df["engine_size_l"],
    bins=[-np.inf, 2.0, 4.0, 6.0, np.inf],
    labels=["up_to_2", "up_to_4", "up_to_6", "more_than_6"],
)

df["engine_size_l_class"].value_counts().sort_index()
# Out:
# engine_size_l_class
# up_to_2         5104
# up_to_4        10327
# up_to_6         4264
# more_than_6      825
# Name: count, dtype: int64

# %%
df["cylinders"].value_counts()
# Out:
# cylinders
# 4     7678
# 6     6950
# 8     4645
# 12     455
# 5      396
# 3      198
# 10     168
# 16      16
# 2       14
# Name: count, dtype: int64

# %% [markdown]
# ## 8. Clustering and Feature Engineering
#
# We created classes for numeric variables to facilitate the model's learning.

# %%
df["cylinders_class"] = pd.cut(
    df["cylinders"],
    bins=[-np.inf, 4, 6, 8, np.inf],
    labels=["up_to_4", "up_to_6", "up_to_8", "more_than_8"],
)

df["cylinders_class"].value_counts().sort_index()
# Out:
# cylinders_class
# up_to_4        7890
# up_to_6        7346
# up_to_8        4645
# more_than_8     639
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20520 entries, 0 to 20520
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_year             20520 non-null  int64
#  1   engine_size_l          20520 non-null  float64
#  2   cylinders              20520 non-null  int64
#  3   transmission           20520 non-null  object
#  4   fuel_type              20520 non-null  str
#  5   city_l_100_km          20520 non-null  float64
#  6   highway_l_100_km       20520 non-null  float64
#  7   combined_l_100_km      20520 non-null  float64
#  8   co2_emissions_g_km     20520 non-null  int64
#  9   vehicle_class_grouped  20520 non-null  str
#  10  engine_size_l_class    20520 non-null  category
#  11  cylinders_class        20520 non-null  category
# dtypes: category(2), float64(4), int64(3), object(1), str(2)
# memory usage: 1.8+ MB

# %%
df = df.drop(columns=["engine_size_l", "cylinders"])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20520 entries, 0 to 20520
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   model_year             20520 non-null  int64
#  1   transmission           20520 non-null  object
#  2   fuel_type              20520 non-null  str
#  3   city_l_100_km          20520 non-null  float64
#  4   highway_l_100_km       20520 non-null  float64
#  5   combined_l_100_km      20520 non-null  float64
#  6   co2_emissions_g_km     20520 non-null  int64
#  7   vehicle_class_grouped  20520 non-null  str
#  8   engine_size_l_class    20520 non-null  category
#  9   cylinders_class        20520 non-null  category
# dtypes: category(2), float64(3), int64(2), object(1), str(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ## 9. Saving of the Treated Base
#
# We exported the final processed dataset to be used in the modeling stage.

# %%
# Exportação do dataset tratado
df.to_parquet(PROCESSED_DATA, index=False)
